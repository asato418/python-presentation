# %%
import pandas as pd
pd.read_csv("population.csv", encoding="SHIFT_JIS")
# Out:
# /usr/lib64/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /usr/lib64/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
#     都道府県  平成12年  平成17年  平成22年  平成27年  平成28年
# 0    東京都  12064  12577  13159  13515  13624
# 1   神奈川県   8490   8792   9048   9126   9145
# 2    大阪府   8805   8817   8865   8839   8833
# 3    愛知県   7043   7255   7411   7483   7507
# 4    埼玉県   6938   7054   7195   7267   7289
# 5    千葉県   5926   6056   6216   6223   6236
# 6    兵庫県   5551   5591   5588   5535   5520
# 7    北海道   5683   5628   5506   5382   5352
# 8    福岡県   5016   5050   5072   5102   5104
# 9    静岡県   3767   3792   3765   3700   3688
# 10   茨城県   2986   2975   2970   2917   2905
# 11   広島県   2879   2877   2861   2844   2837
# 12   京都府   2644   2648   2636   2610   2605
# 13   宮城県   2365   2360   2348   2334   2330
# 14   新潟県   2476   2431   2374   2304   2286
# 15   長野県   2215   2196   2152   2099   2088
# 16   岐阜県   2108   2107   2081   2032   2022
# 17   群馬県   2025   2024   2008   1973   1967
# 18   栃木県   2005   2017   2008   1974   1966
# 19   岡山県   1951   1957   1945   1922   1915
# 20   福島県   2127   2091   2029   1914   1901
# 21   三重県   1857   1867   1855   1816   1808
# 22   熊本県   1859   1842   1817   1786   1774
# 23  鹿児島県   1786   1753   1706   1648   1637
# 24   沖縄県   1318   1362   1393   1434   1439
# 25   滋賀県   1343   1380   1411   1413   1413
# 26   山口県   1528   1493   1451   1405   1394
# 27   愛媛県   1493   1468   1431   1385   1375
# 28   長崎県   1517   1479   1427   1377   1367
# 29   奈良県   1443   1421   1401   1364   1356
# 30   青森県   1476   1437   1373   1308   1293
# 31   岩手県   1416   1385   1330   1280   1268
# 32   大分県   1221   1210   1197   1166   1160
# 33   石川県   1181   1174   1170   1154   1151
# 34   山形県   1244   1216   1169   1124   1113
# 35   宮崎県   1170   1153   1135   1104   1096
# 36   富山県   1121   1112   1093   1066   1061
# 37   秋田県   1189   1146   1086   1023   1010
# 38   香川県   1023   1012    996    976    972
# 39  和歌山県   1070   1036   1002    964    954
# 40   山梨県    888    885    863    835    830
# 41   佐賀県    877    866    850    833    828
# 42   福井県    829    822    806    787    782
# 43   徳島県    824    810    785    756    750
# 44   高知県    814    796    764    728    721
# 45   島根県    762    742    717    694    690
# 46   鳥取県    613    607    589    573    570

# %%
 # %matplotlib inline
 import pandas as pd
 df = pd.read_csv("population.csv", encoding="SHIFT_JIS")
 df.plot.bar(y=['平成28年', '平成12年'])

# %%
import matplotlib as mpl
mpl.__path__
# Out:
# ['/usr/lib64/python3.6/site-packages/matplotlib']

# %%
# !pip install jupyter RISE
# Out:
# Requirement already satisfied: jupyter in /usr/lib/python3.6/site-packages (1.0.0)
# Requirement already satisfied: RISE in /usr/lib64/python3.6/site-packages (5.4.1)
# Requirement already satisfied: qtconsole in /usr/lib/python3.6/site-packages (from jupyter) (4.4.1)
# Requirement already satisfied: notebook in /usr/lib/python3.6/site-packages (from jupyter) (5.6.0)
# Requirement already satisfied: ipykernel in /usr/lib/python3.6/site-packages (from jupyter) (4.8.2)
# Requirement already satisfied: nbconvert in /usr/lib/python3.6/site-packages (from jupyter) (5.3.1)
# Requirement already satisfied: jupyter-console in /usr/lib/python3.6/site-packages (from jupyter) (5.2.0)
# Requirement already satisfied: ipywidgets in /usr/lib/python3.6/site-packages (from jupyter) (7.4.1)
# Requirement already satisfied: jupyter-client>=4.1 in /usr/lib/python3.6/site-packages (from qtconsole->jupyter) (5.2.3)
# Requirement already satisfied: ipython-genutils in /usr/lib/python3.6/site-packages (from qtconsole->jupyter) (0.2.0)
# Requirement already satisfied: jupyter-core in /usr/lib/python3.6/site-packages (from qtconsole->jupyter) (4.4.0)
# Requirement already satisfied: pygments in /usr/lib64/python3.6/site-packages (from qtconsole->jupyter) (2.2.0)
# Requirement already satisfied: traitlets in /usr/lib/python3.6/site-packages (from qtconsole->jupyter) (4.3.2)
# Requirement already satisfied: nbformat in /usr/lib/python3.6/site-packages (from notebook->jupyter) (4.4.0)
# Requirement already satisfied: terminado>=0.8.1 in /usr/lib/python3.6/site-packages (from notebook->jupyter) (0.8.1)
# Requirement already satisfied: jinja2 in /usr/lib64/python3.6/site-packages (from notebook->jupyter) (2.10)
# Requirement already satisfied: tornado>=4 in /usr/lib64/python3.6/site-packages (from notebook->jupyter) (5.1)
# Requirement already satisfied: prometheus-client in /usr/lib/python3.6/site-packages (from notebook->jupyter) (0.3.1)
# Requirement already satisfied: pyzmq>=17 in /usr/lib64/python3.6/site-packages (from notebook->jupyter) (17.1.2)
# Requirement already satisfied: Send2Trash in /usr/lib/python3.6/site-packages (from notebook->jupyter) (1.5.0)
# Requirement already satisfied: ipython>=4.0.0 in /usr/lib/python3.6/site-packages (from ipykernel->jupyter) (6.5.0)
# Requirement already satisfied: testpath in /usr/lib/python3.6/site-packages (from nbconvert->jupyter) (0.3.1)
# Requirement already satisfied: bleach in /usr/lib/python3.6/site-packages (from nbconvert->jupyter) (2.1.3)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/lib/python3.6/site-packages (from nbconvert->jupyter) (0.2.3)
# Requirement already satisfied: mistune>=0.7.4 in /usr/lib/python3.6/site-packages (from nbconvert->jupyter) (0.8.3)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/lib/python3.6/site-packages (from nbconvert->jupyter) (1.4.2)
# Requirement already satisfied: prompt-toolkit<2.0.0,>=1.0.0 in /usr/lib/python3.6/site-packages (from jupyter-console->jupyter) (1.0.15)
# Requirement already satisfied: widgetsnbextension~=3.4.0 in /usr/lib/python3.6/site-packages (from ipywidgets->jupyter) (3.4.1)
# Requirement already satisfied: python-dateutil>=2.1 in /usr/lib/python3.6/site-packages (from jupyter-client>=4.1->qtconsole->jupyter) (2.7.3)
# Requirement already satisfied: decorator in /usr/lib/python3.6/site-packages (from traitlets->qtconsole->jupyter) (4.3.0)
# Requirement already satisfied: six in /usr/lib/python3.6/site-packages (from traitlets->qtconsole->jupyter) (1.11.0)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /usr/lib/python3.6/site-packages (from nbformat->notebook->jupyter) (2.6.0)
# Requirement already satisfied: ptyprocess; os_name != "nt" in /usr/lib/python3.6/site-packages (from terminado>=0.8.1->notebook->jupyter) (0.6.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/lib64/python3.6/site-packages (from jinja2->notebook->jupyter) (1.0)
# Requirement already satisfied: jedi>=0.10 in /usr/lib/python3.6/site-packages (from ipython>=4.0.0->ipykernel->jupyter) (0.12.1)
# Requirement already satisfied: pickleshare in /usr/lib/python3.6/site-packages (from ipython>=4.0.0->ipykernel->jupyter) (0.7.4)
# Requirement already satisfied: backcall in /usr/lib/python3.6/site-packages (from ipython>=4.0.0->ipykernel->jupyter) (0.1.0)
# Requirement already satisfied: simplegeneric>0.8 in /usr/lib/python3.6/site-packages (from ipython>=4.0.0->ipykernel->jupyter) (0.8.1)
# Requirement already satisfied: setuptools>=18.5 in /usr/lib/python3.6/site-packages (from ipython>=4.0.0->ipykernel->jupyter) (39.0.1)
# Requirement already satisfied: pexpect; sys_platform != "win32" in /usr/lib/python3.6/site-packages (from ipython>=4.0.0->ipykernel->jupyter) (4.6.0)
# Requirement already satisfied: html5lib!=1.0b1,!=1.0b2,!=1.0b3,!=1.0b4,!=1.0b5,!=1.0b6,!=1.0b7,!=1.0b8,>=0.99999999pre in /usr/lib/python3.6/site-packages (from bleach->nbconvert->jupyter) (1.0.1)
# Requirement already satisfied: wcwidth in /usr/lib/python3.6/site-packages (from prompt-toolkit<2.0.0,>=1.0.0->jupyter-console->jupyter) (0.1.7)
# Requirement already satisfied: parso>=0.3.0 in /usr/lib/python3.6/site-packages (from jedi>=0.10->ipython>=4.0.0->ipykernel->jupyter) (0.3.1)
# Requirement already satisfied: webencodings in /usr/lib/python3.6/site-packages (from html5lib!=1.0b1,!=1.0b2,!=1.0b3,!=1.0b4,!=1.0b5,!=1.0b6,!=1.0b7,!=1.0b8,>=0.99999999pre->bleach->nbconvert->jupyter) (0.5.1)

# %%
# !jupyter-nbextension install rise --py --sys-prefix
# Out:
# Could not figure out RISE version - using 0.0.0 (package.json not found)
# Installing /usr/lib64/python3.6/site-packages/rise/static -> rise
# Up to date: /usr/share/jupyter/nbextensions/rise/rise.png
# Up to date: /usr/share/jupyter/nbextensions/rise/main.css
# Up to date: /usr/share/jupyter/nbextensions/rise/rise.yaml
# Up to date: /usr/share/jupyter/nbextensions/rise/README.md
# Up to date: /usr/share/jupyter/nbextensions/rise/main.js
# Up to date: /usr/share/jupyter/nbextensions/rise/notes_rise/notes.js
# Up to date: /usr/share/jupyter/nbextensions/rise/notes_rise/index.js
# Up to date: /usr/share/jupyter/nbextensions/rise/notes_rise/notes.html
# Up to date: /usr/share/jupyter/nbextensions/rise/notes_rise/package.json
# Up to date: /usr/share/jupyter/nbextensions/rise/reveal.js/.npmignore
# Up to date: /usr/share/jupyter/nbextensions/rise/reveal.js/Gruntfile.js
# Up to date: /usr/share/jupyter/nbextensions/rise/reveal.js/index.html
# Up to date: /usr/share/jupyter/nbextensions/rise/reveal.js/LICENSE
# Up to date: /usr/share/jupyter/nbextensions/rise/reveal.js/bower.json
# Up to date: /usr/share/jupyter/nbextensions/rise/reveal.js/README.md
# Up to date: /usr/share/jupyter/nbextensions/rise/reveal.js/package.json
# Up to date: /usr/share/jupyter/nbextensions/rise/reveal.js/CONTRIBUTING.md
# Up to date: /usr/share/jupyter/nbextensions/rise/reveal.js/demo.html
# Up to date: /usr/share/jupyter/nbextensions/rise/reveal.js/.travis.yml
# Up to date: /usr/share/jupyter/nbextensions/rise/reveal.js/test/test-markdown-options.js
# Up to date: /usr/share/jupyter/nbextensions/rise/reveal.js/test/test-markdown-external.js
# Up to date: /usr/share/jupyter/nbextensions/rise/reveal.js/test/test.js
# Up to date: /usr/share/jupyter/nbextensions/rise/reveal.js/test/test-markdown-element-attributes.js
# Up to date: /usr/share/jupyter/nbextensions/rise/reveal.js/test/test-markdown.html
# Up to date: /usr/share/jupyter/nbextensions/rise/reveal.js/test/qunit-1.12.0.css
# Up to date: /usr/share/jupyter/nbextensions/rise/reveal.js/test/qunit-1.12.0.js
# Up to date: /usr/share/jupyter/nbextensions/rise/reveal.js/test/test-markdown.js
# Up to date: /usr/share/jupyter/nbextensions/rise/reveal.js/test/test-pdf.html
# Up to date: /usr/share/jupyter/nbextensions/rise/reveal.js/test/test-markdown-slide-attributes.js
# Up to date: /usr/share/jupyter/nbextensions/rise/reveal.js/test/test-markdown-options.html
# Up to date: /usr/share/jupyter/nbextensions/rise/reveal.js/test/simple.md
# Up to date: /usr/share/jupyter/nbextensions/rise/reveal.js/test/test-markdown-slide-attributes.html
# Up to date: /usr/share/jupyter/nbextensions/rise/reveal.js/test/test-markdown-element-attributes.html
# Up to date: /usr/share/jupyter/nbextensions/rise/reveal.js/test/test.html
# Up to date: /usr/share/jupyter/nbextensions/rise/reveal.js/test/test-pdf.js
# Up to date: /usr/share/jupyter/nbextensions/rise/reveal.js/test/test-markdown-external.html
# Up to date: /usr/share/jupyter/nbextensions/rise/reveal.js/test/examples/slide-backgrounds.html
# Up to date: /usr/share/jupyter/nbextensions/rise/reveal.js/test/examples/embedded-media.html
# Up to date: /usr/share/jupyter/nbextensions/rise/reveal.js/test/examples/barebones.html
# Up to date: /usr/share/jupyter/nbextensions/rise/reveal.js/test/examples/slide-transitions.html
# Up to date: /usr/share/jupyter/nbextensions/rise/reveal.js/test/examples/math.html
# Up to date: /usr/share/jupyter/nbextensions/rise/reveal.js/test/examples/assets/image1.png
# Up to date: /usr/share/jupyter/nbextensions/rise/reveal.js/test/examples/assets/image2.png
# Up to date: /usr/share/jupyter/nbextensions/rise/reveal.js/css/reveal.css.upstream
# Up to date: /usr/share/jupyter/nbextensions/rise/reveal.js/css/reveal.css
# Up to date: /usr/share/jupyter/nbextensions/rise/reveal.js/css/reveal.scss
# Up to date: /usr/share/jupyter/nbextensions/rise/reveal.js/css/print/paper.css
# Up to date: /usr/share/jupyter/nbextensions/rise/reveal.js/css/print/pdf.css
# Up to date: /usr/share/jupyter/nbextensions/rise/reveal.js/css/theme/black.css
# Up to date: /usr/share/jupyter/nbextensions/rise/reveal.js/css/theme/blood.css
# Up to date: /usr/share/jupyter/nbextensions/rise/reveal.js/css/theme/beige.css
# Up to date: /usr/share/jupyter/nbextensions/rise/reveal.js/css/theme/serif.css
# Up to date: /usr/share/jupyter/nbextensions/rise/reveal.js/css/theme/README.md
# Up to date: /usr/share/jupyter/nbextensions/rise/reveal.js/css/theme/night.css
# Up to date: /usr/share/jupyter/nbextensions/rise/reveal.js/css/theme/white.css
# Up to date: /usr/share/jupyter/nbextensions/rise/reveal.js/css/theme/solarized.css
# Up to date: /usr/share/jupyter/nbextensions/rise/reveal.js/css/theme/moon.css
# Up to date: /usr/share/jupyter/nbextensions/rise/reveal.js/css/theme/simple.css
# Up to date: /usr/share/jupyter/nbextensions/rise/reveal.js/css/theme/league.css
# Up to date: /usr/share/jupyter/nbextensions/rise/reveal.js/css/theme/sky.css
# Up to date: /usr/share/jupyter/nbextensions/rise/reveal.js/css/theme/source/sky.scss
# Up to date: /usr/share/jupyter/nbextensions/rise/reveal.js/css/theme/source/serif.scss
# Up to date: /usr/share/jupyter/nbextensions/rise/reveal.js/css/theme/source/solarized.scss
# Up to date: /usr/share/jupyter/nbextensions/rise/reveal.js/css/theme/source/white.scss
# Up to date: /usr/share/jupyter/nbextensions/rise/reveal.js/css/theme/source/beige.scss
# Up to date: /usr/share/jupyter/nbextensions/rise/reveal.js/css/theme/source/moon.scss
# Up to date: /usr/share/jupyter/nbextensions/rise/reveal.js/css/theme/source/league.scss
# Up to date: /usr/share/jupyter/nbextensions/rise/reveal.js/css/theme/source/blood.scss
# Up to date: /usr/share/jupyter/nbextensions/rise/reveal.js/css/theme/source/simple.scss
# Up to date: /usr/share/jupyter/nbextensions/rise/reveal.js/css/theme/source/black.scss
# Up to date: /usr/share/jupyter/nbextensions/rise/reveal.js/css/theme/source/night.scss
# Up to date: /usr/share/jupyter/nbextensions/rise/reveal.js/css/theme/template/mixins.scss
# Up to date: /usr/share/jupyter/nbextensions/rise/reveal.js/css/theme/template/theme.scss
# Up to date: /usr/share/jupyter/nbextensions/rise/reveal.js/css/theme/template/settings.scss
# Up to date: /usr/share/jupyter/nbextensions/rise/reveal.js/js/reveal.js
# Up to date: /usr/share/jupyter/nbextensions/rise/reveal.js/plugin/notes-server/client.js
# Up to date: /usr/share/jupyter/nbextensions/rise/reveal.js/plugin/notes-server/index.js
# Up to date: /usr/share/jupyter/nbextensions/rise/reveal.js/plugin/notes-server/notes.html
# Up to date: /usr/share/jupyter/nbextensions/rise/reveal.js/plugin/zoom-js/zoom.js
# Up to date: /usr/share/jupyter/nbextensions/rise/reveal.js/plugin/highlight/highlight.js
# Up to date: /usr/share/jupyter/nbextensions/rise/reveal.js/plugin/markdown/example.md
# Up to date: /usr/share/jupyter/nbextensions/rise/reveal.js/plugin/markdown/marked.js
# Up to date: /usr/share/jupyter/nbextensions/rise/reveal.js/plugin/markdown/example.html
# Up to date: /usr/share/jupyter/nbextensions/rise/reveal.js/plugin/markdown/markdown.js
# Up to date: /usr/share/jupyter/nbextensions/rise/reveal.js/plugin/math/math.js
# Up to date: /usr/share/jupyter/nbextensions/rise/reveal.js/plugin/print-pdf/print-pdf.js
# Up to date: /usr/share/jupyter/nbextensions/rise/reveal.js/plugin/search/search.js
# Up to date: /usr/share/jupyter/nbextensions/rise/reveal.js/plugin/notes/notes.js
# Up to date: /usr/share/jupyter/nbextensions/rise/reveal.js/plugin/notes/notes.html
# Up to date: /usr/share/jupyter/nbextensions/rise/reveal.js/plugin/multiplex/client.js
# Up to date: /usr/share/jupyter/nbextensions/rise/reveal.js/plugin/multiplex/index.js
# Up to date: /usr/share/jupyter/nbextensions/rise/reveal.js/plugin/multiplex/package.json
# Up to date: /usr/share/jupyter/nbextensions/rise/reveal.js/plugin/multiplex/master.js
# Up to date: /usr/share/jupyter/nbextensions/rise/reveal.js/lib/css/zenburn.css
# Up to date: /usr/share/jupyter/nbextensions/rise/reveal.js/lib/js/html5shiv.js
# Up to date: /usr/share/jupyter/nbextensions/rise/reveal.js/lib/js/head.min.js
# Up to date: /usr/share/jupyter/nbextensions/rise/reveal.js/lib/js/classList.js
# Up to date: /usr/share/jupyter/nbextensions/rise/reveal.js/lib/font/source-sans-pro/source-sans-pro.css
# Up to date: /usr/share/jupyter/nbextensions/rise/reveal.js/lib/font/source-sans-pro/source-sans-pro-semibolditalic.eot
# Up to date: /usr/share/jupyter/nbextensions/rise/reveal.js/lib/font/source-sans-pro/LICENSE
# Up to date: /usr/share/jupyter/nbextensions/rise/reveal.js/lib/font/source-sans-pro/source-sans-pro-regular.woff
# Up to date: /usr/share/jupyter/nbextensions/rise/reveal.js/lib/font/source-sans-pro/source-sans-pro-semibold.woff
# Up to date: /usr/share/jupyter/nbextensions/rise/reveal.js/lib/font/source-sans-pro/source-sans-pro-semibolditalic.woff
# Up to date: /usr/share/jupyter/nbextensions/rise/reveal.js/lib/font/source-sans-pro/source-sans-pro-semibolditalic.ttf
# Up to date: /usr/share/jupyter/nbextensions/rise/reveal.js/lib/font/source-sans-pro/source-sans-pro-regular.eot
# Up to date: /usr/share/jupyter/nbextensions/rise/reveal.js/lib/font/source-sans-pro/source-sans-pro-italic.ttf
# Up to date: /usr/share/jupyter/nbextensions/rise/reveal.js/lib/font/source-sans-pro/source-sans-pro-semibold.ttf
# Up to date: /usr/share/jupyter/nbextensions/rise/reveal.js/lib/font/source-sans-pro/source-sans-pro-italic.woff
# Up to date: /usr/share/jupyter/nbextensions/rise/reveal.js/lib/font/source-sans-pro/source-sans-pro-regular.ttf
# Up to date: /usr/share/jupyter/nbextensions/rise/reveal.js/lib/font/source-sans-pro/source-sans-pro-italic.eot
# Up to date: /usr/share/jupyter/nbextensions/rise/reveal.js/lib/font/source-sans-pro/source-sans-pro-semibold.eot
# Up to date: /usr/share/jupyter/nbextensions/rise/reveal.js/lib/font/league-gothic/league-gothic.woff
# Up to date: /usr/share/jupyter/nbextensions/rise/reveal.js/lib/font/league-gothic/league-gothic.css
# Up to date: /usr/share/jupyter/nbextensions/rise/reveal.js/lib/font/league-gothic/LICENSE
# Up to date: /usr/share/jupyter/nbextensions/rise/reveal.js/lib/font/league-gothic/league-gothic.ttf
# Up to date: /usr/share/jupyter/nbextensions/rise/reveal.js/lib/font/league-gothic/league-gothic.eot
# Up to date: /usr/share/jupyter/nbextensions/rise/reveal.js-chalkboard/README.md
# Up to date: /usr/share/jupyter/nbextensions/rise/reveal.js-chalkboard/chalkboard.js
# Up to date: /usr/share/jupyter/nbextensions/rise/reveal.js-chalkboard/package.json
# Up to date: /usr/share/jupyter/nbextensions/rise/reveal.js-chalkboard/img/sponge.png
# Up to date: /usr/share/jupyter/nbextensions/rise/reveal.js-chalkboard/img/whiteboard.png
# Up to date: /usr/share/jupyter/nbextensions/rise/reveal.js-chalkboard/img/boardmarker.png
# Up to date: /usr/share/jupyter/nbextensions/rise/reveal.js-chalkboard/img/chalk.png
# Up to date: /usr/share/jupyter/nbextensions/rise/reveal.js-chalkboard/img/blackboard.png
# - Validating: OK
#
#     To initialize this nbextension in the browser every time the notebook (or other app) loads:
#
#           jupyter nbextension enable rise --py --sys-prefix

# %%
# !jupyter-nbextension enable rise --py --sys-prefix
# Out:
# Could not figure out RISE version - using 0.0.0 (package.json not found)
# Enabling notebook extension rise/main...
#       - Validating: OK

# %% [markdown]
# # Jupyter + RISEによるプレゼンテーション
# ## Asato Takemoto
# ## 2018/9/12

# %% [markdown]
# ## 都道府県別人口の増減
# ![image.png](attachment:image.png)

# %%
import pandas as pd
pd.read_csv("population.csv", encoding="SHIFT_JIS")
# Out:
#     都道府県  平成12年  平成17年  平成22年  平成27年  平成28年
# 0    東京都  12064  12577  13159  13515  13624
# 1   神奈川県   8490   8792   9048   9126   9145
# 2    大阪府   8805   8817   8865   8839   8833
# 3    愛知県   7043   7255   7411   7483   7507
# 4    埼玉県   6938   7054   7195   7267   7289
# 5    千葉県   5926   6056   6216   6223   6236
# 6    兵庫県   5551   5591   5588   5535   5520
# 7    北海道   5683   5628   5506   5382   5352
# 8    福岡県   5016   5050   5072   5102   5104
# 9    静岡県   3767   3792   3765   3700   3688
# 10   茨城県   2986   2975   2970   2917   2905
# 11   広島県   2879   2877   2861   2844   2837
# 12   京都府   2644   2648   2636   2610   2605
# 13   宮城県   2365   2360   2348   2334   2330
# 14   新潟県   2476   2431   2374   2304   2286
# 15   長野県   2215   2196   2152   2099   2088
# 16   岐阜県   2108   2107   2081   2032   2022
# 17   群馬県   2025   2024   2008   1973   1967
# 18   栃木県   2005   2017   2008   1974   1966
# 19   岡山県   1951   1957   1945   1922   1915
# 20   福島県   2127   2091   2029   1914   1901
# 21   三重県   1857   1867   1855   1816   1808
# 22   熊本県   1859   1842   1817   1786   1774
# 23  鹿児島県   1786   1753   1706   1648   1637
# 24   沖縄県   1318   1362   1393   1434   1439
# 25   滋賀県   1343   1380   1411   1413   1413
# 26   山口県   1528   1493   1451   1405   1394
# 27   愛媛県   1493   1468   1431   1385   1375
# 28   長崎県   1517   1479   1427   1377   1367
# 29   奈良県   1443   1421   1401   1364   1356
# 30   青森県   1476   1437   1373   1308   1293
# 31   岩手県   1416   1385   1330   1280   1268
# 32   大分県   1221   1210   1197   1166   1160
# 33   石川県   1181   1174   1170   1154   1151
# 34   山形県   1244   1216   1169   1124   1113
# 35   宮崎県   1170   1153   1135   1104   1096
# 36   富山県   1121   1112   1093   1066   1061
# 37   秋田県   1189   1146   1086   1023   1010
# 38   香川県   1023   1012    996    976    972
# 39  和歌山県   1070   1036   1002    964    954
# 40   山梨県    888    885    863    835    830
# 41   佐賀県    877    866    850    833    828
# 42   福井県    829    822    806    787    782
# 43   徳島県    824    810    785    756    750
# 44   高知県    814    796    764    728    721
# 45   島根県    762    742    717    694    690
# 46   鳥取県    613    607    589    573    570

# %% [markdown]
# # グラフもインタラクティブに簡単に描画できます。

# %%
 # %matplotlib inline
 import pandas as pd
 df = pd.read_csv("population.csv", encoding="SHIFT_JIS")
 df.plot.bar(y=['平成28年', '平成12年'])
